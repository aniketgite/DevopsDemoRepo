# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketgite/DevopsDemoRepo/blob/main/Terraform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -need to create IAM role for creating resources through terraform.and attach that role to ec2 instance.
#
# - need to create file main.tf  ###file name can be anything
